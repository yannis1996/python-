# %%
# 查看当前挂载的数据集目录
# !ls /home/kesci/input/

# %%
# 查看个人持久化工作区文件
# !ls /home/kesci/work/

# %%
# 查看当前kernerl下的package
# !pip list --format=columns

# %%
# 显示cell运行时长
# %load_ext klab-autotime

# %%
from tkinter import*
from tkinter import ttk
#Graphcial user interface
def on_click()：
  print('hello')

# %%
button = ttk.Button()
button.pack()
button['text']='Click me!'
button['command']=on_click
mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3590c0983b18> in <module>
# ----> 1 button = ttk.Button()
#       2 button.pack()
#       3 button['text']='Click me!'
#       4 button['command']=on_click
#       5 mainloop()
#
# NameError: name 'ttk' is not defined

# %%
for i in range(10):
     ttk.Button(text=i).pack(side=LEFT,fill=BOTH)
mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2ff725de9705> in <module>
#       1 for i in range(10):
# ----> 2      ttk.Button(text=i).pack(side=LEFT,fill=BOTH)
#       3 mainloop()
#       4
#
# NameError: name 'ttk' is not defined

# %%
for i in range()
   for j in range(5):
       text='{}.{}'.format(i,j)
       ttk.Button(text=text).grid(row=i,column=j)
mainloop()
from tkinter import*
from tkinterimport ttk
class Calculator(Tk):
    def_init_(self,*args,**kwargs):
        super()._init_(*args,**kwargs)
        self.title('Simple calculator')
       #row 1 
       row=Frame(self)
       row.pack(side=TOP,expand=True,fill=BOTH)
       self.add_button(row,'1')
       self.add_button(row,'2')
       self.add_button(row,'3')
       self.add_button(row,'4')
       #row 2 
       row=Frame(self)
       row.pack(side=TOP,expand=True,fill=BOTH)
       self.add_button(row,'CE')
       self.add_button(row,'C')
       self.add_button(row,'Back')
       self.add_button(row,'/')
#output
       output=ttk.Label(self,textvariable=self.result_string,
       font=())
       
def on_1_click(self)：
   print('1 click')

def on_2_click(self)：
   print('2 click')

def on_3_click(self)：
   print('3 click')

def on_4_click(self)：
   print('4 click')

def on_5_click(self)：
   print('5 click')
   
def on_6_click(self)：
   print('6 click')

def on_7_click(self)：
   print('7 click')
   
def on_8_click(self)：
   print('8 click')
   
def on_9_click(self)：
   print('9 click')
   
def on_add_click(self)
if_name_=='_main_':
    app=Calculator()
    app.mainloop()

def on_equal_click(self):
    print('=clicked')
    if self.operator =='+'
       self.number1=str(float(self.number1)+float(self.number2))
    elif self.operator=='-':
       self.number2=str(float(self.number1)-float(self.number2))
