# %%
# 查看当前挂载的数据集目录
# !ls /home/kesci/input/

# %%
# 查看个人持久化工作区文件
# !ls /home/kesci/work/

# %%
# 查看当前kernerl下的package
# !pip list --format=columns

# %%
# 显示cell运行时长
# %load_ext klab-autotime

# %%
s='abcedf'
s[-5:-1]
# Out:
# 'bced'
# time: 1.97 ms

# %%
str='hello world'
print(str)
# Out:
# hello world
# time: 585 µs

# %%
print(str[0])
# Out:
# h
# time: 591 µs

# %%
print(str[2:5])#输出第3到第5个字符
# Out:
# l
# time: 901 µs

# %%
print(str*2)
# Out:
# hello worldhello world
# time: 553 µs

# %%
list=['1','2','3','4','5']#列表
print(list[1:3])
# Out:
# ['2', '3']
# time: 683 µs

# %%
print(list[2:])
# Out:
# ['3', '4', '5']
# time: 602 µs

# %%
tuple=('1','2')#元组不能二次赋值，相当于只读列表 
#字典：无序的对象集合；列表：有序的对象集合  字典当中的元素是通过键来存取的，而不是通过偏移存取
dict={}
dict['one']="This is one"
dict[2]="This is two"
tinydict={'1':'john','2':'manson'}
print(dict['one'])
print(tinydict['1'])
print(dict.keys())#输出字典的所有键
print(dict.values())#输出字典的所有值
# Out:
# This is one
# john
# dict_keys(['one', 2])
# dict_values(['This is one', 'This is two'])
# time: 1.39 ms
