# %%
# 查看当前挂载的数据集目录
# !ls /home/kesci/input/

# %%
# 查看个人持久化工作区文件
# !ls /home/kesci/work/

# %%
# 查看当前kernerl下的package
# !pip list --format=columns

# %%
# 显示cell运行时长
# %load_ext klab-autotime

# %%
f=open('12.3.ipynb')
f.readline()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-47c7d27d42af> in <module>
# ----> 1 f=open('12.3.ipynb')
#       2 f.readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: '12.3.ipynb'

# %%
lines = f.readlines()
print(lines)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9fca9169834a> in <module>
# ----> 1 lines = f.readlines()
#       2 print(lines)
#
# NameError: name 'f' is not defined

# %%
for line in lines:
    print(line,end='')
f.close()
f.open('test.text','w')
f.write('hello')
import sys
text = sys.stdin.read()
wordcount = len(words)
print('Word count:',wordcount)
import fileinput
for line in fileinput.input(inplace=True):
    line = line.rstrip()
    num = fileinput.lineno()
    print('{:<50}#{:2d}')
def process_line(line):
    print('processing:{}'.format(line))
with open('test.txt')as f:
    while True:
        line=f.readline()
        if not line: break
        process_line(line)
        
from tkinter import *
from tkinter import ttk
from tkinter.scrolledtext import ScrolledText

class SimpleEditor(tk):
    def__init__(self,*args,**kwargs):
        super().__init__(*args,**kwargs)
        self.setup_ui()
        
    def setup_ui(self):
        self.title('Simple editor')
        self.file_name=StringVar()
        self.filename=ttk.Entry(textvariable=self.file_name)
        self.file_name.set('romeo.txt')
        self.filename.pack(side=LEFT,expand=True,fill=x)
